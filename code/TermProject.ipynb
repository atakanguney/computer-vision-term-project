# %%
import pandas as pd

# %%
event_data_path = "../data/bball_dataset_april_4.csv"
bounding_boxes_data_path = "../data/train_test_val_merged_detections_v2_ts_fixed.csv"

# %%
event_data = pd.read_csv(event_data_path, header=None)

# %%
event_data.head()
# Out:
#             0    1    2            3            4            5            6   \
# 0  -VcfnuYRhMU  490  360  2377375.000  2400664.933  2384913.177  2384972.840
# 1  -XPEvIMe05A  490  360  1020386.033  1055254.200  1050422.765  1051247.263
# 2  8Kg9jj9hzGQ  490  360  1227993.433  1273505.566       -1.000  1261500.152
# 3  8Kg9jj9hzGQ  490  360  1227993.433  1273505.566  1254131.452  1255201.545
# 4  8Kg9jj9hzGQ  490  360  1227993.433  1273505.566  1241897.745  1243128.008
#
#          7         8                        9      10
# 0  0.376000  0.242884            layup failure  train
# 1  0.582667  0.288425            layup success   test
# 2 -1.000000 -1.000000            steal success  train
# 3  0.698667  0.445920  other 2-pointer failure  train
# 4  0.548000  0.352941  other 2-pointer failure  train

# %%
event_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14548 entries, 0 to 14547
# Data columns (total 11 columns):
# 0     14548 non-null object
# 1     14548 non-null int64
# 2     14548 non-null int64
# 3     14548 non-null float64
# 4     14548 non-null float64
# 5     14548 non-null float64
# 6     14548 non-null float64
# 7     14548 non-null float64
# 8     14548 non-null float64
# 9     14548 non-null object
# 10    14548 non-null object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
# Columns name got from http://basketballattention.appspot.com/
columns = [
    "#YoutubeId",
    "VideoWidth",
    "VideoHeight",
    "ClipStartTime",
    "ClipEndTime",
    "EventStartTime",
    "EventEndTime",
    "EventStartBallX",
    "EventStartBallY",
    "EventLabel",
    "TrainValOrTest",
]

# %%
event_data.columns = columns

# %%
event_data.head()
# Out:
#     #YoutubeId  VideoWidth  VideoHeight  ClipStartTime  ClipEndTime  \
# 0  -VcfnuYRhMU         490          360    2377375.000  2400664.933
# 1  -XPEvIMe05A         490          360    1020386.033  1055254.200
# 2  8Kg9jj9hzGQ         490          360    1227993.433  1273505.566
# 3  8Kg9jj9hzGQ         490          360    1227993.433  1273505.566
# 4  8Kg9jj9hzGQ         490          360    1227993.433  1273505.566
#
#    EventStartTime  EventEndTime  EventStartBallX  EventStartBallY  \
# 0     2384913.177   2384972.840         0.376000         0.242884
# 1     1050422.765   1051247.263         0.582667         0.288425
# 2          -1.000   1261500.152        -1.000000        -1.000000
# 3     1254131.452   1255201.545         0.698667         0.445920
# 4     1241897.745   1243128.008         0.548000         0.352941
#
#                 EventLabel TrainValOrTest
# 0            layup failure          train
# 1            layup success           test
# 2            steal success          train
# 3  other 2-pointer failure          train
# 4  other 2-pointer failure          train

# %%
bboxes_data = pd.read_csv(bounding_boxes_data_path, header=None)

# %%
bboxes_data.head()
# Out:
#              0          1       2       3       4       5  \
# 0  -KUYDYCwnOQ  518684833  0.3306  0.6090  0.0919  0.3400
# 1  -KUYDYCwnOQ  518684833  0.3359  0.4698  0.0861  0.3161
# 2  -KUYDYCwnOQ  518684833  0.4099  0.3784  0.0841  0.3056
# 3  -KUYDYCwnOQ  518684833  0.5091  0.2676  0.0723  0.2190
# 4  -KUYDYCwnOQ  518684833  0.5394  0.1466  0.0802  0.2086
#
#                        6
# 0   person_0_00511477633
# 1   person_6_00511477633
# 2  person_14_00511477633
# 3  person_10_00511477633
# 4  person_26_00511477633

# %%
columns_bb = [
    "Youtube ID",
    "Time",
    "Top-left x",
    "Top-left y",
    "Width",
    "Height",
    "player-id",
]

# %%
bboxes_data.columns = columns_bb

# %%
bboxes_data.head()
# Out:
#     Youtube ID       Time  Top-left x  Top-left y   Width  Height  \
# 0  -KUYDYCwnOQ  518684833      0.3306      0.6090  0.0919  0.3400
# 1  -KUYDYCwnOQ  518684833      0.3359      0.4698  0.0861  0.3161
# 2  -KUYDYCwnOQ  518684833      0.4099      0.3784  0.0841  0.3056
# 3  -KUYDYCwnOQ  518684833      0.5091      0.2676  0.0723  0.2190
# 4  -KUYDYCwnOQ  518684833      0.5394      0.1466  0.0802  0.2086
#
#                player-id
# 0   person_0_00511477633
# 1   person_6_00511477633
# 2  person_14_00511477633
# 3  person_10_00511477633
# 4  person_26_00511477633

# %%
bboxes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4045698 entries, 0 to 4045697
# Data columns (total 7 columns):
# Youtube ID    object
# Time          int64
# Top-left x    float64
# Top-left y    float64
# Width         float64
# Height        float64
# player-id     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 216.1+ MB
