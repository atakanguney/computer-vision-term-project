# %% [markdown]
# # Import Dataset

# %%
import pandas as pd

# %%
event_data_path = "../data/bball_dataset_april_4.csv"
bounding_boxes_data_path = "../data/train_test_val_merged_detections_v2_ts_fixed.csv"

# %%
event_data = pd.read_csv(event_data_path, header=None)

# %%
event_data.head()
# Out:
#             0    1    2            3            4            5            6   \
# 0  -VcfnuYRhMU  490  360  2377375.000  2400664.933  2384913.177  2384972.840
# 1  -XPEvIMe05A  490  360  1020386.033  1055254.200  1050422.765  1051247.263
# 2  8Kg9jj9hzGQ  490  360  1227993.433  1273505.566       -1.000  1261500.152
# 3  8Kg9jj9hzGQ  490  360  1227993.433  1273505.566  1254131.452  1255201.545
# 4  8Kg9jj9hzGQ  490  360  1227993.433  1273505.566  1241897.745  1243128.008
#
#          7         8                        9      10
# 0  0.376000  0.242884            layup failure  train
# 1  0.582667  0.288425            layup success   test
# 2 -1.000000 -1.000000            steal success  train
# 3  0.698667  0.445920  other 2-pointer failure  train
# 4  0.548000  0.352941  other 2-pointer failure  train

# %%
event_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14548 entries, 0 to 14547
# Data columns (total 11 columns):
# 0     14548 non-null object
# 1     14548 non-null int64
# 2     14548 non-null int64
# 3     14548 non-null float64
# 4     14548 non-null float64
# 5     14548 non-null float64
# 6     14548 non-null float64
# 7     14548 non-null float64
# 8     14548 non-null float64
# 9     14548 non-null object
# 10    14548 non-null object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
# Columns name got from http://basketballattention.appspot.com/
columns = [
    "#YoutubeId",
    "VideoWidth",
    "VideoHeight",
    "ClipStartTime",
    "ClipEndTime",
    "EventStartTime",
    "EventEndTime",
    "EventStartBallX",
    "EventStartBallY",
    "EventLabel",
    "TrainValOrTest",
]

# %%
event_data.columns = columns

# %%
event_data[event_data["TrainValOrTest"] == "train"]
# Out:
#         #YoutubeId  VideoWidth  VideoHeight  ClipStartTime  ClipEndTime  \
# 0      -VcfnuYRhMU         490          360    2377375.000  2400664.933
# 2      8Kg9jj9hzGQ         490          360    1227993.433  1273505.566
# 3      8Kg9jj9hzGQ         490          360    1227993.433  1273505.566
# 4      8Kg9jj9hzGQ         490          360    1227993.433  1273505.566
# 5      8Kg9jj9hzGQ         490          360    1227993.433  1273505.566
# 8      EWewYijB7h8         490          360    3939802.533  3961057.100
# 9      EWewYijB7h8         490          360    3939802.533  3961057.100
# 10     KxK9H8w4wWk         490          360    3258255.000  3293323.367
# 11     KxK9H8w4wWk         490          360    3258255.000  3293323.367
# 12     LxiVvBYlutY         490          360    2299964.333  2333798.133
# 13     LxiVvBYlutY         490          360    2299964.333  2333798.133
# 14     N_bE2ep-CMo         490          360    2817815.000  2843040.200
# 17     hCpiwFmKlDs         490          360     960960.000   983782.800
# 18     nrZTpOdHzyE         490          360     750750.000   772772.000
# 19     pLWjvrMmirI         490          360    3459956.500  3506469.633
# 20     pLWjvrMmirI         490          360    3459956.500  3506469.633
# 21     pLWjvrMmirI         490          360    3459956.500  3506469.633
# 14547     2192016.474   2193628.455         0.766667         0.252372
#
#                     EventLabel TrainValOrTest
# 0                layup failure          train
# 2                steal success          train
# 3      other 2-pointer failure          train
# 4      other 2-pointer failure          train
# 5                layup success          train
# 8                layup failure          train
# 9                steal success          train
# 10     other 2-pointer success          train
# 11     other 2-pointer failure          train
# 12               steal success          train
# 13          free-throw success          train
# 14     other 2-pointer success          train
# 17           3-pointer failure          train
# 18           3-pointer failure          train
# 19           3-pointer failure          train
# 20               layup failure          train
# 21     other 2-pointer success          train
# 22     other 2-pointer success          train
# 23               steal success          train
# 24           3-pointer failure          train
# 25           3-pointer success          train
# 28               steal success          train
# 29           3-pointer failure          train
# 30     other 2-pointer success          train
# 31          free-throw success          train
# 32          free-throw failure          train
# 33               steal success          train
# 34     other 2-pointer success          train
# 35               layup success          train
# 36           3-pointer failure          train
# ...                        ...            ...
# 14515  other 2-pointer success          train
# 14516  other 2-pointer failure          train
# 14517       free-throw failure          train
# 14518       free-throw success          train
# 14519  other 2-pointer failure          train
# 14520        3-pointer failure          train
# 14521        3-pointer failure          train
# 14522            layup failure          train
# 14523            layup failure          train
# 14524            steal success          train
# 14525  other 2-pointer failure          train
# 14526       free-throw failure          train
# 14528            steal success          train
# 14529  other 2-pointer failure          train
# 14530            layup success          train
# 14531            layup failure          train
# 14532       free-throw success          train
# 14533        3-pointer failure          train
# 14534            steal success          train
# 14535            steal success          train
# 14536  other 2-pointer failure          train
# 14537            layup success          train
# 14538  other 2-pointer failure          train
# 14539        3-pointer failure          train
# 14540        slam dunk success          train
# 14541  other 2-pointer failure          train
# 14542  other 2-pointer failure          train
# 14543  other 2-pointer failure          train
# 14544  other 2-pointer success          train
# 14547        3-pointer failure          train
#
# [11436 rows x 11 columns]

# %%
bboxes_data = pd.read_csv(bounding_boxes_data_path, header=None)

# %%
bboxes_data.head()
# Out:
#              0          1       2       3       4       5  \
# 0  -KUYDYCwnOQ  518684833  0.3306  0.6090  0.0919  0.3400
# 1  -KUYDYCwnOQ  518684833  0.3359  0.4698  0.0861  0.3161
# 2  -KUYDYCwnOQ  518684833  0.4099  0.3784  0.0841  0.3056
# 3  -KUYDYCwnOQ  518684833  0.5091  0.2676  0.0723  0.2190
# 4  -KUYDYCwnOQ  518684833  0.5394  0.1466  0.0802  0.2086
#
#                        6
# 0   person_0_00511477633
# 1   person_6_00511477633
# 2  person_14_00511477633
# 3  person_10_00511477633
# 4  person_26_00511477633

# %%
columns_bb = [
    "Youtube ID",
    "Time",
    "Top-left x",
    "Top-left y",
    "Width",
    "Height",
    "player-id",
]

# %%
bboxes_data.columns = columns_bb

# %%
import numpy as np

# %%
np.unique(bboxes_data[(bboxes_data["Youtube ID"] == "-KUYDYCwnOQ")]["player-id"].values).shape
# Out:
# (1236,)

# %%
bboxes_data[(bboxes_data["Youtube ID"] == "-KUYDYCwnOQ") & (bboxes_data["player-id"].str.contains("person_0"))]
# Out:
#         Youtube ID        Time  Top-left x  Top-left y   Width  Height  \
# 14765  person_0_04256018433
# 14772  person_0_04256018433
# 14779  person_0_04256018433
# 14786  person_0_04256018433
# 14793  person_0_04256018433
# 14800  person_0_04256018433
# 14806  person_0_04256018433
# 14813  person_0_04256018433
# 14820  person_0_04256018433
# 14828  person_0_04256018433
# 14835  person_0_04256018433
# 14842  person_0_04256018433
# 14849  person_0_04256018433
# 14856  person_0_04256018433
# 14864  person_0_04256018433
# 14871  person_0_04256018433
# 14879  person_0_04256018433
# 14888  person_0_04256018433
# 14897  person_0_04256018433
# 14903  person_0_04256018433
# 14907  person_0_04256018433
# 15374  person_0_04382511467
# 15378  person_0_04382511467
# 15384  person_0_04382511467
# 15390  person_0_04382511467
# 15396  person_0_04382511467
# 15401  person_0_04382511467
# 15408  person_0_04382511467
# 15414  person_0_04382511467
#
# [339 rows x 7 columns]

# %%
bboxes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4045698 entries, 0 to 4045697
# Data columns (total 7 columns):
# Youtube ID    object
# Time          int64
# Top-left x    float64
# Top-left y    float64
# Width         float64
# Height        float64
# player-id     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 216.1+ MB

# %% [markdown]
# # Download Video Clip

# %%
from pytube import YouTube

# %%
youtube_base = "http://youtube.com/watch?v="

# %%
video_id = event_data["#YoutubeId"].iloc[1]

# %%
video_id
# Out:
# '-XPEvIMe05A'

# %%
yt = YouTube(youtube_base + video_id)

# %%
yt.streams.first()
# Out:
# <Stream: itag="43" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp8.0" acodec="vorbis">

# %%
st.
# Out:
# ['vp8.0', 'vorbis']

# %%
yt.streams.first()
# Out:
# '/Users/atakan1/Desktop/Computer Vision/project/code/2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm'

# %% [markdown]
# # Take event clips from video

# %%
sample = event_data[event_data["#YoutubeId"] == video_id]

# %%
import time
var = 1051247263
s, ms = divmod(var, 1e6)
s, ms = int(s), int(ms / 1e3)
"{}.{:03d}".format(time.strftime('%H:%M:%S', time.gmtime(s)), ms)
# Out:
# '00:17:31.247'

# %%
import time
def microseconds2datetime(microseconds):
    s, ms = divmod(microseconds, 1e6)
    s, ms = int(s), int(ms / 1e3)
    return "{}.{:03d}".format(time.strftime("%H:%M:%S", time.gmtime(s)), ms)

# %%
sample.sort_values(by="EventEndTime")
# Out:
#         #YoutubeId  VideoWidth  VideoHeight  ClipStartTime  ClipEndTime  \
# 13088  -XPEvIMe05A         490          360       5372.033    28395.033
# 5511   -XPEvIMe05A         490          360      55088.367    96963.534
# 5510   -XPEvIMe05A         490          360      55088.367    96963.534
# 13721  -XPEvIMe05A         490          360      98698.600   140440.300
# 4435   -XPEvIMe05A         490          360     333833.500   379679.300
# 4434   -XPEvIMe05A         490          360     333833.500   379679.300
# 12788  -XPEvIMe05A         490          360     505238.067   526692.834
# 12787  -XPEvIMe05A         490          360     505238.067   526692.834
# 7836   -XPEvIMe05A         490          360     705705.000   728360.967
# 7838   -XPEvIMe05A         490          360     705705.000   728360.967
# 7837   -XPEvIMe05A         490          360     705705.000   728360.967
# 7839   -XPEvIMe05A         490          360     705705.000   728360.967
# 7210           -1.000   3739788.880        -1.000000        -1.000000
# 6217           -1.000   3800271.504        -1.000000        -1.000000
# 6218           -1.000   3813185.931        -1.000000        -1.000000
# 6220           -1.000   3825193.845        -1.000000        -1.000000
# 6219           -1.000   3831199.944        -1.000000        -1.000000
# 2453           -1.000   3899489.280        -1.000000        -1.000000
# 2455           -1.000   3917112.459        -1.000000        -1.000000
# 2454           -1.000   3921598.628        -1.000000        -1.000000
#
#                     EventLabel TrainValOrTest
# 13088  other 2-pointer failure           test
# 5511         3-pointer failure           test
# 5510   other 2-pointer success           test
# 13721  other 2-pointer failure           test
# 4435   other 2-pointer failure           test
# 4434             steal success           test
# 12788            steal success           test
# 12787        slam dunk success           test
# 7836             steal success           test
# 7838             steal success           test
# 7837         3-pointer failure           test
# 7839             layup success           test
# 12411  other 2-pointer success           test
# 8112             steal success           test
# 1                layup success           test
# 1538   other 2-pointer failure           test
# 1537   other 2-pointer failure           test
# 1539             steal success           test
# 13248  other 2-pointer success           test
# 9034   other 2-pointer failure           test
# 9035   other 2-pointer failure           test
# 14487            steal success           test
# 14490        3-pointer failure           test
# 14489            steal success           test
# 14488            layup success           test
# 4835   other 2-pointer failure           test
# 1615         3-pointer failure           test
# 13249        3-pointer failure           test
# 50           3-pointer failure           test
# 49     other 2-pointer failure           test
# ...                        ...            ...
# 731          3-pointer failure           test
# 732    other 2-pointer failure           test
# 10022  other 2-pointer failure           test
# 10023        3-pointer success           test
# 3051   other 2-pointer failure           test
# 3052             steal success           test
# 2879         3-pointer success           test
# 2880         3-pointer success           test
# 9931   other 2-pointer failure           test
# 9930             steal success           test
# 9929             steal success           test
# 9928             layup failure           test
# 2661             steal success           test
# 2662             steal success           test
# 5509             layup success           test
# 3085         3-pointer failure           test
# 11692            layup failure           test
# 5468         slam dunk success           test
# 3525         3-pointer failure           test
# 6628         3-pointer failure           test
# 9037        free-throw success           test
# 9036         3-pointer failure           test
# 7210         3-pointer success           test
# 6217        free-throw success           test
# 6218        free-throw success           test
# 6220         3-pointer failure           test
# 6219         3-pointer failure           test
# 2453             steal success           test
# 2455             steal success           test
# 2454   other 2-pointer failure           test
#
# [65 rows x 11 columns]

# %%
sample_bbox = bboxes_data[bboxes_data["Youtube ID"] == video_id]

# %%
sample_bbox
# Out:
#         Youtube ID        Time  Top-left x  Top-left y   Width  Height  \
# 30164  -XPEvIMe05A    19586233      0.1432      0.1933  0.0886  0.2189
# 30165  -XPEvIMe05A    19586233      0.2764      0.5402  0.0900  0.3240
# 30166  -XPEvIMe05A    19586233      0.2991      0.2584  0.1121  0.2205
# 30167  -XPEvIMe05A    19586233      0.3627      0.4677  0.1043  0.2661
# 30168  -XPEvIMe05A    19586233      0.4409      0.2818  0.0944  0.1966
# 30169  -XPEvIMe05A    19586233      0.5279      0.2671  0.0736  0.2266
# 30170  -XPEvIMe05A    19586233      0.5645      0.4091  0.0818  0.2663
# 30171  -XPEvIMe05A    19586233      0.5771      0.3760  0.0937  0.2641
# %%
unique = np.unique(sample_bbox.sort_values(by="Time").Time.values)

# %%
unique[0], unique[-1]
# Out:
# (19586233, 3926522600)

# %%
microseconds2datetime(3926522600 - 19586233)
# Out:
# '01:05:06.936'

# %% [markdown]
# # Extracting clips from sample video and subsampling

# %%
import numpy as np
import cv2

# %%
import subprocess

# %%
def extract_clips_ffmpeg(video_path, starts, ends):
    """Extracts clips from video between starts-ends
    Parameters
    ==========
    video_path: str
        Video to be extracted clips
    starts: list
        Start times of clips
    ends: list
        End times of clips
    """
    
    video_format = video_path.split(".")[1]
    
    for i, (start, end) in enumerate(zip(starts, ends)):
        cmd = [
            "/usr/local/bin/ffmpeg",
            "-i", video_path,
            "-ss", str(start / 1000),
            "-to", str(end / 1000),
            "-q:v", "10",
            "-r", "5", # paper says frame rate is 6 but according to bounding boxes data it is 5
            "-vcodec", "vp8",
            "-acodec", "libvorbis",
            "-y", "clips/clip-{}.{}".format(i, video_format),
        ]
        
        subprocess.run(cmd)

# %%
import os
import subprocess

# %%
def extract_events_ffmpeg(video_path, event_ends):
    """Extract events from the video
    Parameters
    ==========
    
    video_path: str
        Path of the video to be extracted events
    event_ends: list
        List of timestamp of event ends
    """
    
    if not os.path.exists("events"):
        os.mkdir("events")
        
    video_format = video_path.split(".")[1]
    
    for i, end in enumerate(event_ends):
        start = end - 4e3
        cmd = [
            "/usr/local/bin/ffmpeg",
            "-i", video_path,
            "-ss", str(start / 1e3),
            "-to", str(end / 1e3),
            "-q:v", "10",
            "-r", "6",
            "-vcodec", "vp8",
            "-acodec", "libvorbis",
            "-y", "events/event_{}.{}".format(i, video_format)
        ]
        
        print(" ".join(cmd))
        subprocess.run(cmd, stderr=subprocess.PIPE)

# %%
# It is important to sort by clip start time
sample = sample.sort_values(by=["ClipStartTime"])

starts, ends = np.unique(sample["ClipStartTime"].values), np.unique(sample["ClipEndTime"].values)

video_path = "2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm"

# %%
extract_clips_ffmpeg(video_path, starts, ends) # Run once

# %%
sample = sample.sort_values(by="EventEndTime")
event_ends = sample["EventEndTime"].values

# %%
video_path = "2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm"

# %%
extract_events_ffmpeg(video_path, event_ends)
# Out:
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 20.470539000000002 -to 24.470539000000002 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_0.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 79.480476 -to 83.480476 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_1.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 88.365245 -to 92.365245 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_2.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 129.67056200000002 -to 133.67056200000002 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_3.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 352.27286799999996 -to 356.27286799999996 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_4.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 367.170249 -to 371.170249 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_5.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 517.401075 -to 521.401075 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_6.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 520.294162 -to 524.294162 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_7.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 710.684626 -to 714.684626 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_8.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 712.246 -to 716.246 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_9.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 721.182902 -to 725.182902 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_10.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 723.119635 -to 727.119635 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_11.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 779.900765 -to 783.900765 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_12.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 916.685286 -to 920.685286 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_13.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 1047.247263 -to 1051.247263 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_14.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 1102.8175190000002 -to 1106.8175190000002 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_15.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 1105.6966470000002 -to 1109.6966470000002 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_16.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 1122.293059 -to 1126.293059 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_17.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 1203.513678 -to 1207.513678 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_18.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 1292.390969 -to 1296.390969 -q:v 10 -r 6 -vcodec vp8 -acodec libvorbis -y events/event_19.webm
# /usr/local/bin/ffmpeg -i 2003 NCAA Basketball Regional Final - Syracuse vs Oklahoma.webm -ss 
# 30167  person_49_00002902900
# 30168  person_40_00002902900

# %%
sample.sort_values(by=["EventEndTime"]).head() # Time is in milisecond
# Out:
#         #YoutubeId  VideoWidth  VideoHeight  ClipStartTime  ClipEndTime  \
# 13088  -XPEvIMe05A         490          360       5372.033    28395.033
# 5511   -XPEvIMe05A         490          360      55088.367    96963.534
# 5510   -XPEvIMe05A         490          360      55088.367    96963.534
# 13721  -XPEvIMe05A         490          360      98698.600   140440.300
# 4435   -XPEvIMe05A         490          360     333833.500   379679.300
#
#        EventStartTime  EventEndTime  EventStartBallX  EventStartBallY  \
# 13088       23476.902     24470.539         0.514667         0.110057
# 5511        81834.513     83480.476         0.646667         0.110057
# 5510        90915.495     92365.245         0.432000         0.161290
# 13721      132698.774    133670.562         0.514667         0.303605
# 4435       355230.054    356272.868         0.596000         0.178368
#
#                     EventLabel TrainValOrTest
# 13088  other 2-pointer failure           test
# 5511         3-pointer failure           test
# 5510   other 2-pointer success           test
# 13721  other 2-pointer failure           test
# 4435   other 2-pointer failure           test

# %%
clip_start, clip_end = sample.iloc[0]["ClipStartTime"], sample.iloc[0]["ClipEndTime"]

# %%
clip_start, clip_end = int(clip_start * 1000), int(clip_end * 1000) # convert milisecond to microsecond

# %%
def frame(clip, event_start, event_end, clip_start):
    """Get frame from `clip` at given `time_`
    
    Parameters
    ----------
    clip: VideoReader
        Object to read clip
    event_start: float or int
        Start time of event in microsecods
    event_end: float or int
        End time of event in microsecond
    clip_start: float or int
        Clip start time to use as offset value in microseconds
    
    """

    relative_start_time = event_start - clip_start
    relative_end_time = event_end - clip_start
    
    frames = []
    
    while True:
        
        cur_timestamp = int(clip.get(cv2.CAP_PROP_POS_MSEC) * 1000) # Convert miliseconds into microseconds
        ret, frame = clip.read()

        if cur_timestamp >= relative_start_time and cur_timestamp <= relative_end_time:
            frames.append(frame)
        
        if cur_timestamp > relative_end_time:
            break
        
    return frames

# %%
clip_start
# Out:
# 5372033

# %%
event_start, event_end = int(sample.iloc[0]["ClipStartTime"] * 1000), int(sample.iloc[0]["ClipEndTime"] * 1000)

# %%
event_start
# Out:
# 5372033

# %%
event_end
# Out:
# 28395033

# %%
sample_bboxes = sample_bbox[(sample_bbox.Time >= event_start) & (sample_bbox.Time <= event_end)]

# %%
l = sample_bboxes.Time.values
unique, counts = np.unique(l, return_counts=True)
dict(zip(unique, counts))
# Out:
# {19586233: 9,
#  19786433: 9,
#  19986633: 10,
#  20186833: 10,
#  20387033: 10,
#  20587233: 8,
#  20787433: 9,
#  20987633: 9,
#  21187833: 10,
#  21388033: 8,
#  21588233: 10,
#  21788433: 9,
#  21988633: 7,
#  22188833: 9,
#  22389033: 10,
#  22589233: 10,
#  22789433: 10,
#  22989633: 9,
#  23189833: 8,
#  23390033: 8,
#  23590233: 9,
#  23790433: 8,
#  23990633: 8,
#  24190833: 9,
#  24391033: 8,
#  24591233: 8,
#  24791433: 7,
#  24991633: 6,
#  25191833: 6,
#  25392033: 7,
#  25592233: 5,
#  25792433: 4,
#  25992633: 5,
#  26192833: 4,
#  26393033: 3,
#  26593233: 3,
#  26793433: 5,
#  26993633: 5,
#  27193833: 5,
#  27394033: 5,
#  27594233: 5,
#  27794433: 5,
#  27994633: 5,
#  28194833: 5}

# %%
sample_bboxes.head()
# Out:
#         Youtube ID      Time  Top-left x  Top-left y   Width  Height  \
# 30164  -XPEvIMe05A  19586233      0.1432      0.1933  0.0886  0.2189
# 30165  -XPEvIMe05A  19586233      0.2764      0.5402  0.0900  0.3240
# 30166  -XPEvIMe05A  19586233      0.2991      0.2584  0.1121  0.2205
# 30167  -XPEvIMe05A  19586233      0.3627      0.4677  0.1043  0.2661
# 30168  -XPEvIMe05A  19586233      0.4409      0.2818  0.0944  0.1966
#
#                    player-id
# 30164  person_27_00002902900
# 30165  person_45_00002902900
# 30166  person_44_00002902900
# 30167  person_49_00002902900
# 30168  person_40_00002902900

# %%
event_start, event_end = int(sample_bboxes["Time"].iloc[0]), int(sample_bboxes["Time"].iloc[-1])

# %%
event_start
# Out:
# 19586233

# %%
event_end
# Out:
# 28194833

# %%
import cv2

# %%
starts[0], ends[0]
# Out:
# (5372.033, 28395.033)

# %%
cap = cv2.VideoCapture("clips/clip-0.webm")

# %%
sample_frames = frame(cap, event_start, event_end, clip_start=clip_start)
cap.release()

# %%
len(sample_frames)
# Out:
# 43

# %%
width = 490
height = 360

# %%
xs = [width * x for x in sample_bboxes["Top-left x"].iloc[9:17].values] 
ys = [height * y for y in sample_bboxes["Top-left y"].iloc[9:17].values]
widths = [width * w for w in sample_bboxes["Width"].iloc[9:17].values]
heights = [height * h for h in sample_bboxes["Height"].iloc[9:17].values]

# %%
frame_ = sample_frames[1]

# %%
n_boxes = len(xs)

# %%
n_boxes
# Out:
# 8

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
# Create figure and axes
fig,ax = plt.subplots(1, figsize=(20, 10))

# Display the image
ax.imshow(cv2.cvtColor(frame_, cv2.COLOR_BGR2RGB))

for i in range(n_boxes):
    rect = patches.Rectangle((xs[i], ys[i]), widths[i], heights[i],linewidth=5,edgecolor='r',facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

# %%
im = cv2.cvtColor(frame_, cv2.COLOR_BGR2RGB)
l = np.int(np.ceil(n_boxes/2))
fig = plt.figure(figsize=(20, 10))
for i in range(n_boxes):
    
    ax = fig.add_subplot(2, l, i+1)
    ax.imshow(im[int(ys[i]):int(ys[i] + heights[i]), int(xs[i]):int(xs[i] + widths[i])])

# %%
def extract_frames_from_event(event_path):
    """Yields frames from given event
    
    Parameters
    ==========
    event_path: str
        Path of the event
    """
    cap = cv2.VideoCapture(event_path)
    cur_timestamp = int(cap.get(cv2.CAP_PROP_POS_MSEC) * 1000)
    success, frame = cap.read()
    
    while success:
        yield frame, cur_timestamp
        success, frame = cap.read()
        cur_timestamp = int(cap.get(cv2.CAP_PROP_POS_MSEC) * 1000)
        
    cap.release()

# %%
test_event = "events/event_0.webm"
frames = []
titles = []
for frame, time in extract_frames_from_event(test_event):
    im = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frames.append(im)
    titles.append(time)
    
fig, axes = plt.subplots(len(frames), 1, figsize=(60, 60))
for i, frame in enumerate(frames):
    axes[i].set_title(titles[i])
    # print(frame)
    axes[i].imshow(frame)

# %%
def extract_players_from_frame(frame, bounding_boxes, width, height):
    """Extract Players Regions
    
    Parameters
    ==========
    frame: np.ndarray
        Frame
    bounding_boxes: list
        List of tuples (top_left_x, top_left_y, width, height)
    """
    
    players_regions = []
    
    bounding_boxes = [(int(width * x), int(height * y), int(width * w), int(height * h)) for x, y, w, h in bounding_boxes]

    for x, y, w, h in bounding_boxes:
        players_regions.append(frame[y:y+h, x:x+w])
        
    return players_regions

# %%
sample = sample.sort_values(by="EventEndTime")

# %%
events_endtime = sample.EventEndTime.values
events_map = dict(zip((events_endtime * 1000).astype(np.int_), ["events/event_{}.webm".format(i) for i in range(len(events_endtime))]))

# %%
events_map
# Out:
# {24470539: 'events/event_0.webm',
#  83480476: 'events/event_1.webm',
#  92365245: 'events/event_2.webm',
#  133670562: 'events/event_3.webm',
#  356272867: 'events/event_4.webm',
#  371170249: 'events/event_5.webm',
#  521401075: 'events/event_6.webm',
#  524294162: 'events/event_7.webm',
#  714684625: 'events/event_8.webm',
#  716246000: 'events/event_9.webm',
#  725182902: 'events/event_10.webm',
#  727119635: 'events/event_11.webm',
#  783900765: 'events/event_12.webm',
#  920685286: 'events/event_13.webm',
#  1051247263: 'events/event_14.webm',
#  1106817519: 'events/event_15.webm',
#  1109696647: 'events/event_16.webm',
#  1126293059: 'events/event_17.webm',
#  1207513678: 'events/event_18.webm',
#  1296390969: 'events/event_19.webm',
#  1307774838: 'events/event_20.webm',
#  1610159915: 'events/event_21.webm',
#  1618318035: 'events/event_22.webm',
#  1620297826: 'events/event_23.webm',
#  1621691215: 'events/event_24.webm',
#  1675624747: 'events/event_25.webm',
#  1817759667: 'events/event_26.webm',
#  1858911000: 'events/event_27.webm',
#  1902845421: 'events/event_28.webm',
#  1917411553: 'events/event_29.webm',
#  1937746086: 'events/event_30.webm',
#  2021024826: 'events/event_31.webm',
#  2028829997: 'events/event_32.webm',
#  2174513539: 'events/event_33.webm',
#  2180631452: 'events/event_34.webm',
#  2299313444: 'events/event_35.webm',
#  2301403381: 'events/event_36.webm',
#  2338536508: 'events/event_37.webm',
#  2342502373: 'events/event_38.webm',
#  2370969121: 'events/event_39.webm',
#  2373882175: 'events/event_40.webm',
#  2481531071: 'events/event_41.webm',
#  2504116908: 'events/event_42.webm',
#  2543977028: 'events/event_43.webm',
#  2562399208: 'events/event_44.webm',
#  2564320478: 'events/event_45.webm',
#  2572361012: 'events/event_46.webm',
#  2652439395: 'events/event_47.webm',
#  2654108000: 'events/event_48.webm',
#  2832084971: 'events/event_49.webm',
#  2919597314: 'events/event_50.webm',
#  3144729767: 'events/event_51.webm',
#  3289596466: 'events/event_52.webm',
#  3317049479: 'events/event_53.webm',
#  3564732216: 'events/event_54.webm',
#  3624307486: 'events/event_55.webm',
#  3641496813: 'events/event_56.webm',
#  3739788880: 'events/event_57.webm',
#  3800271503: 'events/event_58.webm',
#  3813185931: 'events/event_59.webm',
#  3825193845: 'events/event_60.webm',
#  3831199943: 'events/event_61.webm',
#  3899489280: 'events/event_62.webm',
#  3917112459: 'events/event_63.webm',
#  3921598628: 'events/event_64.webm'}

# %%
event_bboxtimes_map = {end: sample_bbox.loc[(end - 4e6 <= sample_bbox.Time) & (sample_bbox.Time <= end), "Time"].values for end in events_map}

# %%
def find_bboxestime_of_frame(relative_timestamp, end_timestamp, event_bboxtimes_map):
    bboxtimes_of_event = event_bboxtimes_map[end_timestamp]
    
    start_timestamp = end_timestamp - 4e6
    absolute_timestamp = relative_timestamp + start_timestamp
    
    idx = (np.abs(bboxtimes_of_event - absolute_timestamp)).argmin()
    
    return bboxtimes_of_event[idx]

# %%
sample_bboxes.loc[sample_bboxes.Time == 24391033, ["Top-left x", "Top-left y", "Width", "Height", "player-id"]].values
# Out:
# array([[0.0567, 0.482, 0.0996, 0.3115, 'person_56_00002902900'],
#        [0.1903, 0.176, 0.1057, 0.2412, 'person_63_00002902900'],
#        [0.2857, 0.2523, 0.0964, 0.2558, 'person_57_00002902900'],
#        [0.3096, 0.4141, 0.1012, 0.341, 'person_40_00002902900'],
#        [0.3672, 0.1868, 0.0959, 0.2435, 'person_62_00002902900'],
#        [0.407, 0.2673, 0.09, 0.3031, 'person_60_00002902900'],
#        [0.625, 0.3808, 0.1018, 0.2944, 'person_58_00002902900'],
#        [0.7166, 0.309, 0.0862, 0.2734, 'person_45_00002902900']],
#       dtype=object)

# %%
def extract_players_from_frames(event_path, event_bboxtimes_map, end_timestamp, bboxes_data):
    for frame, relative_timestamp in extract_frames_from_event(event_path):
        bboxestime = find_bboxestime_of_frame(relative_timestamp, end_timestamp, event_bboxtimes_map)
        bboxes = bboxes_data.loc[bboxes_data.Time == bboxestime, ["Top-left x", "Top-left y", "Width", "Height", "player-id"]].values
        
        player_regions = extract_players_from_frame(frame, bboxes[:, :4], 490, 360)
        player_dict = dict(zip(bboxes[:, 4], player_regions))
        
        yield frame, player_dict

# %%
for frame, player_dict in extract_players_from_frames(test_event, event_bboxtimes_map, 24470539, sample_bbox):
    # print(len(player_dict))
    fig, axes = plt.subplots(len(player_dict) + 1, 1, figsize=(60, 60))
    axes[0].imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    for i, player_id in enumerate(player_dict):
        axes[i + 1].set_title(player_id)
        axes[i + 1].imshow(cv2.cvtColor(player_dict[player_id], cv2.COLOR_BGR2RGB))
        
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cfaf743e1b9f> in <module>
# ----> 1 for frame, player_dict in extract_players_from_frames(test_event, event_bboxtimes_map, 24470539, sample_bbox):
#       2     # print(len(player_dict))
#       3     fig, axes = plt.subplots(len(player_dict) + 1, 1, figsize=(60, 60))
#       4     axes[0].imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
#       5     for i, player_id in enumerate(player_dict):
#
# NameError: name 'extract_players_from_frames' is not defined
